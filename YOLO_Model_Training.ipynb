# %%
from google.colab import drive #Mounting the drive to access datasets
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !unzip '/content/drive/MyDrive/photogauge/custom_data.zip' -d '/content/drive/MyDrive/photogauge/'
# Out:
# Archive:  /content/drive/MyDrive/photogauge/custom_data.zip
#   inflating: /content/drive/MyDrive/photogauge/custom_data/1.jpg
#   inflating: /content/drive/MyDrive/photogauge/custom_data/1.txt
#   inflating: /content/drive/MyDrive/photogauge/custom_data/10.jpg
#   inflating: /content/drive/MyDrive/photogauge/custom_data/10.txt
#   inflating: /content/drive/MyDrive/photogauge/custom_data/100.jpg
#   inflating: /content/drive/MyDrive/photogauge/custom_data/100.txt
#   inflating: /content/drive/MyDrive/photogauge/custom_data/101.jpg
#   inflating: /content/drive/MyDrive/photogauge/custom_data/101.txt
#   inflating: /content/drive/MyDrive/photogauge/custom_data/102.jpg
#   inflating: /content/drive/MyDrive/photogauge/custom_data/102.txt
#   inflating: /content/drive/MyDrive/photogauge/custom_data/103.jpg
#   inflating: /content/drive/MyDrive/photogauge/custom_data/103.txt
#   inflating: /content/drive/MyDrive/photogauge/custom_data/104.jpg
# ...

# %%
# !git clone 'https://github.com/AlexeyAB/darknet.git' '/content/drive/MyDrive/photogauge/darknet' #Installing darknet
# Out:
# Cloning into '/content/drive/MyDrive/photogauge/darknet'...
# remote: Enumerating objects: 15376, done.
# remote: Total 15376 (delta 0), reused 0 (delta 0), pack-reused 15376
# Receiving objects: 100% (15376/15376), 14.01 MiB | 6.97 MiB/s, done.
# Resolving deltas: 100% (10339/10339), done.
# Checking out files: 100% (2050/2050), done.

# %%
# %cd /content/drive/MyDrive/photogauge/darknet
# Out:
# /content/drive/MyDrive/photogauge/darknet

# %%
# !make
# Out:
# chmod +x *.sh
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/image_opencv.cpp -o obj/image_opencv.o
# ./src/image_opencv.cpp: In function ‘void draw_detections_cv_v3(void**, detection*, int, float, char**, image**, int, int)’:
# ./src/image_opencv.cpp:946:23: warning: variable ‘rgb’ set but not used [-Wunused-but-set-variable]
#                  float rgb[3];
#                        ^~~
# ./src/image_opencv.cpp: In function ‘void draw_train_loss(char*, void**, int, float, float, int, int, float, int, char*, float, int, int, double)’:
# ./src/image_opencv.cpp:1147:13: warning: this ‘if’ clause does not guard... [-Wmisleading-indentation]
#              if (iteration_old == 0)
#              ^~
# ...

# %%
# %cd /content/drive/MyDrive/photogauge
# Out:
# /content/drive/MyDrive/photogauge

# %%
# !darknet/darknet #Checking if the makefile is loaded properly
# Out:
# usage: darknet/darknet <function>

# %%
# !python custom_data/creating-files-data-and-name.py

# %%
# !python custom_data/creating-train-and-test-txt-files.py

# %%
# !darknet/darknet detector train custom_data/labelled_data.data darknet/cfg/yolov3_custom.cfg custom_weight/darknet53.conv.74 -dont_show #Training the model
# Out:
# Streaming output truncated to the last 5000 lines.
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 0.000000, iou_loss = 0.000000, total_loss = 0.000000
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000002, iou_loss = 0.000000, total_loss = 0.000002
#  total_bbox = 68907, rewritten_bbox = 0.123355 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.887659), count: 1, class_loss = 0.056686, iou_loss = 0.088038, total_loss = 0.144724
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 0.000794, iou_loss = 0.000000, total_loss = 0.000794
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000144, iou_loss = 0.000000, total_loss = 0.000144
# ...
